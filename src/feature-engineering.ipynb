# %%
# Core data analysis libraries
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"  # to make jupyter print all outputs, not just the last one
from IPython.core.display import HTML  # to pretty print pandas df and be able to copy them over (e.g. to ppt slides)

# %%
# Load datasets
# Each dataset represents a different aspect of movie data

expert_df = pd.read_csv("../cleaned_data/expert_reviews_clean.csv")

user_df = pd.read_csv(
    "../cleaned_data/user_reviews_clean.csv",
    low_memory=False  # avoids dtype inference warnings
)

meta_df = pd.read_csv("../cleaned_data/meta_clean.csv")

sales_df = pd.read_csv("../cleaned_data/sales_clean.csv")
